# %%
# !unzip '/content/archive (30).zip'
# Out:
# Archive:  /content/archive (30).zip
#   inflating: ObesityDataSet.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/ObesityDataSet.csv')
df.head(12)
# Out:
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   Female  21.0    1.62    64.0                            yes   no   2.0
# 1   Female  21.0    1.52    56.0                            yes   no   3.0
# 2     Male  23.0    1.80    77.0                            yes   no   2.0
# 3     Male  27.0    1.80    87.0                             no   no   3.0
# 4     Male  22.0    1.78    89.8                             no   no   2.0
# 5     Male  29.0    1.62    53.0                             no  yes   2.0
# 6   Female  23.0    1.50    55.0                            yes  yes   3.0
# 7     Male  22.0    1.64    53.0                             no   no   2.0
# 8     Male  24.0    1.78    64.0                            yes  yes   3.0
# 9     Male  22.0    1.72    68.0                            yes  yes   2.0
# 10    Male  26.0    1.85   105.0                            yes  yes   3.0
# ...

# %%
df.isnull()
# Out:
#       Gender    Age  Height  Weight  family_history_with_overweight   FAVC  \
# 0      False  False   False   False                           False  False
# 1      False  False   False   False                           False  False
# 2      False  False   False   False                           False  False
# 3      False  False   False   False                           False  False
# 4      False  False   False   False                           False  False
# ...      ...    ...     ...     ...                             ...    ...
# 2106   False  False   False   False                           False  False
# 2107   False  False   False   False                           False  False
# 2108   False  False   False   False                           False  False
# 2109   False  False   False   False                           False  False
# 2110   False  False   False   False                           False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
# Encoding

# 1) Label encoding  2) One hot encoding 3)manual encoding

# %%
df['Gender'].value_counts()
# Out:
# Male      1068
# Female    1043
# Name: Gender, dtype: int64

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight
# 2  Public_Transportation  Normal_Weight

# %%
# Manual encoding

df['Gender'] = df['Gender'].replace({'Male':0,'Female':1})

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                            yes   no   2.0
# 1       1  21.0    1.52    56.0                            yes   no   3.0
# 2       0  23.0    1.80    77.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight
# 2  Public_Transportation  Normal_Weight

# %%
df['FAVC'].value_counts()
# Out:
# yes    1866
# no      245
# Name: FAVC, dtype: int64

# %%
df['FAVC'] = df['FAVC'].replace({'yes':1,'no':0})

# %%
df.head(2)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                            yes     0   2.0
# 1       1  21.0    1.52    56.0                            yes     0   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE       CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0         no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0  Sometimes
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight

# %%
df['family_history_with_overweight'].value_counts()
# Out:
# yes    1726
# no      385
# Name: family_history_with_overweight, dtype: int64

# %%
df['family_history_with_overweight'] = df['family_history_with_overweight'].replace({'yes':1,'no':0})

# %%
df.head(2)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE       CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0         no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0  Sometimes
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight

# %%
pd.get_dummies(df['CAEC'])
# Out:
#       Always  Frequently  Sometimes  no
# 0          0           0          1   0
# 1          0           0          1   0
# 2          0           0          1   0
# 3          0           0          1   0
# 4          0           0          1   0
# ...      ...         ...        ...  ..
# 2106       0           0          1   0
# 2107       0           0          1   0
# 2108       0           0          1   0
# 2109       0           0          1   0
# 2110       0           0          1   0
#
# [2111 rows x 4 columns]

# %%
df['CAEC'].value_counts()
# Out:
# Sometimes     1765
# Frequently     242
# Always          53
# no              51
# Name: CAEC, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['CAEC'] = le.fit_transform(df['CAEC'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  3.0     2    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  3.0     2   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  3.0     2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
# Hari # Srikanth # Saumya
#  0       2          1         This is how label encoder works

# %%
df['CALC'].value_counts()
# Out:
# Sometimes     1401
# no             639
# Frequently      70
# Always           1
# Name: CALC, dtype: int64

# %%
df['CALC'] = le.fit_transform(df['CALC'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC SMOKE  CH2O  SCC  FAF  TUE  CALC                 MTRANS  \
# 0  3.0     2    no   2.0   no  0.0  1.0     3  Public_Transportation
# 1  3.0     2   yes   3.0  yes  3.0  0.0     2  Public_Transportation
# 2  3.0     2    no   2.0   no  2.0  1.0     1  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
le.inverse_transform([3])
# Out:
# array(['no'], dtype=object)
